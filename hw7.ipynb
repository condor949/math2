# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
import seaborn as sns
# %matplotlib inline

print('Задание 1')
print('Составляем уравнение для площади.')
display(Math(r"""P=2(a+b) = 144\\
144/2 = 72 = a+b\\
S = ab"""))
print('a = x, b = 72 - x')
display(Math(r"""S=x(72-x)"""))
print('C помощью производной найдем наибольшее и наименьшее значение.')
display(Math(r"""(72x-x^2)'=72-2x = 0\\
a = x = 36\\
b = 72 - x = 36\\
S = 1296"""))
# Out:
# Задание 1
# Составляем уравнение для площади.
# $\displaystyle P=2(a+b) = 144\\
# 144/2 = 72 = a+b\\
# S = ab$
# a = x, b = 72 - x
# $\displaystyle S=x(72-x)$
# C помощью производной найдем наибольшее и наименьшее значение.
# $\displaystyle (72x-x^2)'=72-2x = 0\\
# a = x = 36\\
# b = 72 - x = 36\\
# S = 1296$
